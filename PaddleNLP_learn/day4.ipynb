# %% [markdown]
# # 作业
#
# - 补全程序中的代码，理解其含义，并跑通整个项目；
# - 报名参加[千言数据集：信息抽取比赛](https://aistudio.baidu.com/aistudio/competition/detail/46)。

# %% [markdown]
# # 基于预训练模型完成实体关系抽取
#
# 信息抽取旨在从非结构化自然语言文本中提取结构化知识，如实体、关系、事件等。对于给定的自然语言句子，根据预先定义的schema集合，抽取出所有满足schema约束的SPO三元组。
#
# 例如，「妻子」关系的schema定义为：
# {
#     S_TYPE: 人物,
#     P: 妻子,
#     O_TYPE: {
#         @value: 人物
#     }
# }
#
# 该示例展示了如何使用PaddleNLP快速完成实体关系抽取，参与[千言信息抽取-关系抽取比赛](https://aistudio.baidu.com/aistudio/competition/detail/46)打榜。

# %%
# 安装paddlenlp最新版本
# !pip install --upgrade paddlenlp

# %cd relation_extraction/

# %% [markdown]
# ## 关系抽取介绍
#
# 针对 DuIE2.0 任务中多条、交叠SPO这一抽取目标，比赛对标准的 'BIO' 标注进行了扩展。
# 对于每个 token，根据其在实体span中的位置（包括B、I、O三种），我们为其打上三类标签，并且根据其所参与构建的predicate种类，将 B 标签进一步区分。给定 schema 集合，对于 N 种不同 predicate，以及头实体/尾实体两种情况，我们设计对应的共 2*N 种 B 标签，再合并 I 和 O 标签，故每个 token 一共有 (2*N+2) 个标签，如下图所示。
#
#
# <div align="center">
# <img src="https://ai-studio-static-online.cdn.bcebos.com/f984664777b241a9b43ef843c9b752f33906c8916bc146a69f7270b5858bee63" width="500" height="400" alt="标注策略" align=center />
# </div>
#
# ### 评价方法
#
# 对测试集上参评系统输出的SPO结果和人工标注的SPO结果进行精准匹配，采用F1值作为评价指标。注意，对于复杂O值类型的SPO，必须所有槽位都精确匹配才认为该SPO抽取正确。针对部分文本中存在实体别名的问题，使用百度知识图谱的别名词典来辅助评测。F1值的计算方式如下：
#
# F1 = (2 * P * R) / (P + R)，其中
#
# - P = 测试集所有句子中预测正确的SPO个数 / 测试集所有句子中预测出的SPO个数
# - R = 测试集所有句子中预测正确的SPO个数 / 测试集所有句子中人工标注的SPO个数

# %% [markdown]
# ### Step1：构建模型
#
# 该任务可以看作一个序列标注任务，所以基线模型采用的是ERNIE序列标注模型。
#
# **PaddleNLP提供了ERNIE预训练模型常用序列标注模型，可以通过指定模型名字完成一键加载。PaddleNLP为了方便用户处理数据，内置了对于各个预训练模型对应的Tokenizer，可以完成文本token化，转token ID，文本长度截断等操作。**
#
# 文本数据处理直接调用tokenizer即可输出模型所需输入数据。

# %%
import os
import json
from paddlenlp.transformers import ErnieForTokenClassification, ErnieTokenizer

label_map_path = os.path.join('data', "predicate2id.json")

if not (os.path.exists(label_map_path) and os.path.isfile(label_map_path)):
    sys.exit("{} dose not exists or is not a file.".format(label_map_path))
with open(label_map_path, 'r', encoding='utf8') as fp:
    label_map = json.load(fp)
    
num_classes = (len(label_map.keys()) - 2) * 2 + 2

# 补齐代码，理解TokenClassification接口含义，理解关系抽取标注体系和类别数由来
model = ErnieForTokenClassification.from_pretrained("ernie-1.0",num_classes=num_classes)
tokenizer = ErnieTokenizer.from_pretrained("ernie-1.0")

inputs = tokenizer(text="请输入测试样例", max_seq_len=20)
# Out:
# [2021-06-13 10:12:03,178] [    INFO] - Downloading https://paddlenlp.bj.bcebos.com/models/transformers/ernie/ernie_v1_chn_base.pdparams and saved to /home/aistudio/.paddlenlp/models/ernie-1.0
# [2021-06-13 10:12:03,181] [    INFO] - Downloading ernie_v1_chn_base.pdparams from https://paddlenlp.bj.bcebos.com/models/transformers/ernie/ernie_v1_chn_base.pdparams
# 100%|██████████| 392507/392507 [00:06<00:00, 65041.61it/s]
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1297: UserWarning: Skip loading for classifier.weight. classifier.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1297: UserWarning: Skip loading for classifier.bias. classifier.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# [2021-06-13 10:12:14,237] [    INFO] - Downloading vocab.txt from https://paddlenlp.bj.bcebos.com/models/transformers/ernie/vocab.txt
# 100%|██████████| 90/90 [00:00<00:00, 21001.86it/s]

# %% [markdown]
# ### Step2：加载并处理数据
#
#
# 从比赛官网下载数据集，解压存放于data/目录下并重命名为train_data.json, dev_data.json, test_data.json.
#
# 我们可以加载自定义数据集。通过继承[`paddle.io.Dataset`](https://www.paddlepaddle.org.cn/documentation/docs/zh/api/paddle/io/Dataset_cn.html#dataset)，自定义实现`__getitem__` 和 `__len__`两个方法。

# %%
from typing import Optional, List, Union, Dict

import numpy as np
import paddle
from tqdm import tqdm
from paddlenlp.utils.log import logger

from data_loader import parse_label, DataCollator, convert_example_to_feature
from extract_chinese_and_punct import ChineseAndPunctuationExtractor


class DuIEDataset(paddle.io.Dataset):
    """
    Dataset of DuIE.
    """

    def __init__(
            self,
            input_ids: List[Union[List[int], np.ndarray]],
            seq_lens: List[Union[List[int], np.ndarray]],
            tok_to_orig_start_index: List[Union[List[int], np.ndarray]],
            tok_to_orig_end_index: List[Union[List[int], np.ndarray]],
            labels: List[Union[List[int], np.ndarray, List[str], List[Dict]]]):
        super(DuIEDataset, self).__init__()

        self.input_ids = input_ids
        self.seq_lens = seq_lens
        self.tok_to_orig_start_index = tok_to_orig_start_index
        self.tok_to_orig_end_index = tok_to_orig_end_index
        self.labels = labels

    def __len__(self):
        if isinstance(self.input_ids, np.ndarray):
            return self.input_ids.shape[0]
        else:
            return len(self.input_ids)

    def __getitem__(self, item):
        return {
            "input_ids": np.array(self.input_ids[item]),
            "seq_lens": np.array(self.seq_lens[item]),
            "tok_to_orig_start_index":
            np.array(self.tok_to_orig_start_index[item]),
            "tok_to_orig_end_index": np.array(self.tok_to_orig_end_index[item]),
            # If model inputs is generated in `collate_fn`, delete the data type casting.
            "labels": np.array(
                self.labels[item], dtype=np.float32),
        }

    @classmethod
    def from_file(cls,
                  file_path: Union[str, os.PathLike],
                  tokenizer: ErnieTokenizer,
                  max_length: Optional[int]=512,
                  pad_to_max_length: Optional[bool]=None):
        assert os.path.exists(file_path) and os.path.isfile(
            file_path), f"{file_path} dose not exists or is not a file."
        label_map_path = os.path.join(
            os.path.dirname(file_path), "predicate2id.json")
        assert os.path.exists(label_map_path) and os.path.isfile(
            label_map_path
        ), f"{label_map_path} dose not exists or is not a file."
        with open(label_map_path, 'r', encoding='utf8') as fp:
            label_map = json.load(fp)
        chineseandpunctuationextractor = ChineseAndPunctuationExtractor()

        input_ids, seq_lens, tok_to_orig_start_index, tok_to_orig_end_index, labels = (
            [] for _ in range(5))
        dataset_scale = sum(1 for line in open(file_path, 'r'))
        logger.info("Preprocessing data, loaded from %s" % file_path)
        with open(file_path, "r", encoding="utf-8") as fp:
            lines = fp.readlines()
            for line in tqdm(lines):
                example = json.loads(line)
                input_feature = convert_example_to_feature(
                    example, tokenizer, chineseandpunctuationextractor,
                    label_map, max_length, pad_to_max_length)
                input_ids.append(input_feature.input_ids)
                seq_lens.append(input_feature.seq_len)
                tok_to_orig_start_index.append(
                    input_feature.tok_to_orig_start_index)
                tok_to_orig_end_index.append(
                    input_feature.tok_to_orig_end_index)
                labels.append(input_feature.labels)

        return cls(input_ids, seq_lens, tok_to_orig_start_index,
                   tok_to_orig_end_index, labels)

# %%
data_path = 'data'
batch_size = 32
max_seq_length = 128

# train_file_path = os.path.join(data_path, 'train_data.json')
train_file_path = os.path.join(data_path, 'train.json')
train_dataset = DuIEDataset.from_file(
    train_file_path, tokenizer, max_seq_length, True)
train_batch_sampler = paddle.io.BatchSampler(
    train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
collator = DataCollator()
train_data_loader = paddle.io.DataLoader(
    dataset=train_dataset,
    batch_sampler=train_batch_sampler,
    collate_fn=collator)

# eval_file_path = os.path.join(data_path, 'dev_data.json')
eval_file_path = os.path.join(data_path, 'dev.json')
test_dataset = DuIEDataset.from_file(
    eval_file_path, tokenizer, max_seq_length, True)
test_batch_sampler = paddle.io.BatchSampler(
    test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)
test_data_loader = paddle.io.DataLoader(
    dataset=test_dataset,
    batch_sampler=test_batch_sampler,
    collate_fn=collator)
# Out:
# [2021-06-13 10:12:36,555] [    INFO] - Preprocessing data, loaded from data/train.json
# 100%|██████████| 171293/171293 [05:16<00:00, 540.37it/s]
# [2021-06-13 10:17:53,971] [    INFO] - Preprocessing data, loaded from data/dev.json
# 100%|██████████| 20674/20674 [00:38<00:00, 531.48it/s]

# %% [markdown]
# ### Step3：定义损失函数和优化器，开始训练
#
# 我们选择均方误差作为损失函数，使用[`paddle.optimizer.AdamW`](https://www.paddlepaddle.org.cn/documentation/docs/zh/api/paddle/optimizer/adamw/AdamW_cn.html#adamw)作为优化器。
#
#
#
# 在训练过程中，模型保存在当前目录checkpoints文件夹下。同时在训练的同时使用官方评测脚本进行评估，输出P/R/F1指标。
# 在验证集上F1可以达到69.42。

# %%
import paddle.nn as nn

class BCELossForDuIE(nn.Layer):
    def __init__(self, ):
        super(BCELossForDuIE, self).__init__()
        self.criterion = nn.BCEWithLogitsLoss(reduction='none')

    def forward(self, logits, labels, mask):
        loss = self.criterion(logits, labels)
        mask = paddle.cast(mask, 'float32')
        loss = loss * mask.unsqueeze(-1)
        loss = paddle.sum(loss.mean(axis=2), axis=1) / paddle.sum(mask, axis=1)
        loss = loss.mean()
        return loss

# %%
from utils import write_prediction_results, get_precision_recall_f1, decoding

@paddle.no_grad()
def evaluate(model, criterion, data_loader, file_path, mode):
    """
    mode eval:
    eval on development set and compute P/R/F1, called between training.
    mode predict:
    eval on development / test set, then write predictions to \
        predict_test.json and predict_test.json.zip \
        under /home/aistudio/relation_extraction/data dir for later submission or evaluation.
    """
    example_all = []
    with open(file_path, "r", encoding="utf-8") as fp:
        for line in fp:
            example_all.append(json.loads(line))
    id2spo_path = os.path.join(os.path.dirname(file_path), "id2spo.json")
    with open(id2spo_path, 'r', encoding='utf8') as fp:
        id2spo = json.load(fp)

    model.eval()
    loss_all = 0
    eval_steps = 0
    formatted_outputs = []
    current_idx = 0
    for batch in tqdm(data_loader, total=len(data_loader)):
        eval_steps += 1
        input_ids, seq_len, tok_to_orig_start_index, tok_to_orig_end_index, labels = batch
        logits = model(input_ids=input_ids)
        mask = (input_ids != 0).logical_and((input_ids != 1)).logical_and((input_ids != 2))
        loss = criterion(logits, labels, mask)
        loss_all += loss.numpy().item()
        probs = F.sigmoid(logits)
        logits_batch = probs.numpy()
        seq_len_batch = seq_len.numpy()
        tok_to_orig_start_index_batch = tok_to_orig_start_index.numpy()
        tok_to_orig_end_index_batch = tok_to_orig_end_index.numpy()
        formatted_outputs.extend(decoding(example_all[current_idx: current_idx+len(logits)],
                                          id2spo,
                                          logits_batch,
                                          seq_len_batch,
                                          tok_to_orig_start_index_batch,
                                          tok_to_orig_end_index_batch))
        current_idx = current_idx+len(logits)
    loss_avg = loss_all / eval_steps
    print("eval loss: %f" % (loss_avg))

    if mode == "predict":
        predict_file_path = os.path.join("/home/aistudio/relation_extraction/data", 'predictions.json')
    else:
        predict_file_path = os.path.join("/home/aistudio/relation_extraction/data", 'predict_eval.json')

    predict_zipfile_path = write_prediction_results(formatted_outputs,
                                                    predict_file_path)

    if mode == "eval":
        precision, recall, f1 = get_precision_recall_f1(file_path,
                                                        predict_zipfile_path)
        os.system('rm {} {}'.format(predict_file_path, predict_zipfile_path))
        return precision, recall, f1
    elif mode != "predict":
        raise Exception("wrong mode for eval func")

# %%
from paddlenlp.transformers import LinearDecayWithWarmup

learning_rate = 2e-5
num_train_epochs = 4
warmup_ratio = 0.06

criterion = BCELossForDuIE()
# Defines learning rate strategy.
steps_by_epoch = len(train_data_loader)
num_training_steps = steps_by_epoch * num_train_epochs
lr_scheduler = LinearDecayWithWarmup(learning_rate, num_training_steps, warmup_ratio)
optimizer = paddle.optimizer.AdamW(
    learning_rate=lr_scheduler,
    parameters=model.parameters(),
    apply_decay_param_fun=lambda x: x in [
        p.name for n, p in model.named_parameters()
        if not any(nd in n for nd in ["bias", "norm"])])

# %%
# 模型参数保存路径
# !mkdir checkpoints2

# %% [markdown]
# ### Step4：提交预测结果
#
# 加载训练保存的模型加载后进行预测。
#
# **NOTE:** 注意设置用于预测的模型参数路径。

# %%
import time
import paddle.nn.functional as F
from visualdl import LogWriter

writer = LogWriter("./log")

# Starts training.
global_step = 0
logging_steps = 50
save_steps = 10000
num_train_epochs = 4
output_dir = 'checkpoints2'
tic_train = time.time()
model.train()
for epoch in range(num_train_epochs):
    print("\n=====start training of %d epochs=====" % epoch)
    tic_epoch = time.time()
    for step, batch in enumerate(train_data_loader):
        input_ids, seq_lens, tok_to_orig_start_index, tok_to_orig_end_index, labels = batch
        logits = model(input_ids=input_ids)
        mask = (input_ids != 0).logical_and((input_ids != 1)).logical_and(
            (input_ids != 2))
        loss = criterion(logits, labels, mask)
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.clear_gradients()
        loss_item = loss.numpy().item()

        if global_step % logging_steps == 0:
            print(
                "epoch: %d / %d, steps: %d / %d, loss: %f, speed: %.2f step/s"
                % (epoch, num_train_epochs, step, steps_by_epoch,
                    loss_item, logging_steps / (time.time() - tic_train)))
            tic_train = time.time()

        if global_step % save_steps == 0 and global_step != 0:
            print("\n=====start evaluating ckpt of %d steps=====" %
                    global_step)
            precision, recall, f1 = evaluate(
                model, criterion, test_data_loader, eval_file_path, "eval")
            print("precision: %.2f\t recall: %.2f\t f1: %.2f\t" %
                    (100 * precision, 100 * recall, 100 * f1))
            print("saving checkpoing model_%d.pdparams to %s " %
                    (global_step, output_dir))
            paddle.save(model.state_dict(),
                        os.path.join(output_dir, 
                                        "model_%d.pdparams" % global_step))
            model.train()
        writer.add_scalar(tag="eval/loss", step=step, value=(loss))
        global_step += 1
    tic_epoch = time.time() - tic_epoch
    
    print("epoch time footprint: %d hour %d min %d sec" %
            (tic_epoch // 3600, (tic_epoch % 3600) // 60, tic_epoch % 60))

# Does final evaluation.
print("\n=====start evaluating last ckpt of %d steps=====" %
        global_step)
precision, recall, f1 = evaluate(model, criterion, test_data_loader,
                                    eval_file_path, "eval")
print("precision: %.2f\t recall: %.2f\t f1: %.2f\t" %
        (100 * precision, 100 * recall, 100 * f1))
paddle.save(model.state_dict(),
            os.path.join(output_dir,
                            "model_%d.pdparams" % global_step))
print("\n=====training complete=====")
# Out:
# =====start training of 0 epochs=====
# epoch: 0 / 4, steps: 0 / 5352, loss: 0.739375, speed: 103.54 step/s
# epoch: 0 / 4, steps: 50 / 5352, loss: 0.727217, speed: 4.20 step/s
# epoch: 0 / 4, steps: 100 / 5352, loss: 0.689026, speed: 4.20 step/s
# epoch: 0 / 4, steps: 150 / 5352, loss: 0.606149, speed: 4.25 step/s
# epoch: 0 / 4, steps: 200 / 5352, loss: 0.385602, speed: 4.23 step/s
# epoch: 0 / 4, steps: 250 / 5352, loss: 0.287204, speed: 4.23 step/s
# epoch: 0 / 4, steps: 300 / 5352, loss: 0.242306, speed: 4.24 step/s
# epoch: 0 / 4, steps: 350 / 5352, loss: 0.211428, speed: 4.21 step/s
# epoch: 0 / 4, steps: 400 / 5352, loss: 0.184249, speed: 4.24 step/s
# epoch: 0 / 4, steps: 450 / 5352, loss: 0.159731, speed: 4.17 step/s
# epoch: 0 / 4, steps: 500 / 5352, loss: 0.139214, speed: 4.23 step/s
# epoch: 0 / 4, steps: 550 / 5352, loss: 0.121043, speed: 4.24 step/s
# epoch: 0 / 4, steps: 600 / 5352, loss: 0.104189, speed: 4.07 step/s
# epoch: 0 / 4, steps: 650 / 5352, loss: 0.091819, speed: 3.99 step/s
# epoch: 0 / 4, steps: 700 / 5352, loss: 0.079497, speed: 4.06 step/s
# epoch: 0 / 4, steps: 750 / 5352, loss: 0.068342, speed: 4.06 step/s
# epoch: 0 / 4, steps: 800 / 5352, loss: 0.061442, speed: 4.07 step/s
# epoch: 0 / 4, steps: 850 / 5352, loss: 0.054289, speed: 4.07 step/s
# epoch: 0 / 4, steps: 900 / 5352, loss: 0.048528, speed: 3.97 step/s
# epoch: 0 / 4, steps: 950 / 5352, loss: 0.043864, speed: 4.08 step/s
# epoch: 0 / 4, steps: 1000 / 5352, loss: 0.040380, speed: 4.06 step/s
# epoch: 0 / 4, steps: 1050 / 5352, loss: 0.035875, speed: 4.08 step/s
# epoch: 0 / 4, steps: 1100 / 5352, loss: 0.031169, speed: 4.10 step/s
# epoch: 0 / 4, steps: 1150 / 5352, loss: 0.030173, speed: 4.11 step/s
# epoch: 0 / 4, steps: 1200 / 5352, loss: 0.028332, speed: 4.10 step/s
# epoch: 0 / 4, steps: 1250 / 5352, loss: 0.027259, speed: 4.17 step/s
# epoch: 0 / 4, steps: 1300 / 5352, loss: 0.023964, speed: 4.20 step/s
# epoch: 0 / 4, steps: 1350 / 5352, loss: 0.022834, speed: 4.18 step/s
# epoch: 0 / 4, steps: 1400 / 5352, loss: 0.021388, speed: 4.16 step/s
# epoch: 0 / 4, steps: 1450 / 5352, loss: 0.019576, speed: 4.19 step/s
# epoch: 0 / 4, steps: 1500 / 5352, loss: 0.018158, speed: 4.20 step/s
# epoch: 0 / 4, steps: 1550 / 5352, loss: 0.016588, speed: 4.20 step/s
# epoch: 0 / 4, steps: 1600 / 5352, loss: 0.016118, speed: 4.23 step/s
# epoch: 0 / 4, steps: 1650 / 5352, loss: 0.015037, speed: 4.18 step/s
# epoch: 0 / 4, steps: 1700 / 5352, loss: 0.014438, speed: 4.03 step/s
# epoch: 0 / 4, steps: 1750 / 5352, loss: 0.012455, speed: 4.04 step/s
# epoch: 0 / 4, steps: 1800 / 5352, loss: 0.012542, speed: 4.02 step/s
# epoch: 0 / 4, steps: 1850 / 5352, loss: 0.011450, speed: 4.05 step/s
# epoch: 0 / 4, steps: 1900 / 5352, loss: 0.011543, speed: 4.04 step/s
# epoch: 0 / 4, steps: 1950 / 5352, loss: 0.011521, speed: 4.07 step/s
# epoch: 0 / 4, steps: 2000 / 5352, loss: 0.010578, speed: 4.07 step/s
# epoch: 0 / 4, steps: 2050 / 5352, loss: 0.011802, speed: 4.08 step/s
# epoch: 0 / 4, steps: 2100 / 5352, loss: 0.010153, speed: 4.05 step/s
# epoch: 0 / 4, steps: 2150 / 5352, loss: 0.009496, speed: 4.09 step/s
# epoch: 0 / 4, steps: 2200 / 5352, loss: 0.009915, speed: 4.13 step/s
# epoch: 0 / 4, steps: 2250 / 5352, loss: 0.009202, speed: 4.18 step/s
# epoch: 0 / 4, steps: 2300 / 5352, loss: 0.009732, speed: 4.22 step/s
# epoch: 0 / 4, steps: 2350 / 5352, loss: 0.009390, speed: 4.23 step/s
# epoch: 0 / 4, steps: 2400 / 5352, loss: 0.008033, speed: 4.21 step/s
# epoch: 0 / 4, steps: 2450 / 5352, loss: 0.008307, speed: 4.20 step/s
# epoch: 0 / 4, steps: 2500 / 5352, loss: 0.008645, speed: 4.18 step/s
# epoch: 0 / 4, steps: 2550 / 5352, loss: 0.008091, speed: 4.23 step/s
# epoch: 0 / 4, steps: 2600 / 5352, loss: 0.007919, speed: 4.17 step/s
# epoch: 0 / 4, steps: 2650 / 5352, loss: 0.007864, speed: 4.18 step/s
# epoch: 0 / 4, steps: 2700 / 5352, loss: 0.006845, speed: 4.20 step/s
# epoch: 0 / 4, steps: 2750 / 5352, loss: 0.007534, speed: 4.22 step/s
# epoch: 0 / 4, steps: 2800 / 5352, loss: 0.006833, speed: 4.25 step/s
# epoch: 0 / 4, steps: 2850 / 5352, loss: 0.008165, speed: 4.19 step/s
# epoch: 0 / 4, steps: 2900 / 5352, loss: 0.006804, speed: 4.21 step/s
# epoch: 0 / 4, steps: 2950 / 5352, loss: 0.007125, speed: 3.92 step/s
# epoch: 0 / 4, steps: 3000 / 5352, loss: 0.006529, speed: 4.01 step/s
# epoch: 0 / 4, steps: 3050 / 5352, loss: 0.005888, speed: 4.01 step/s
# epoch: 0 / 4, steps: 3100 / 5352, loss: 0.005723, speed: 4.00 step/s
# epoch: 0 / 4, steps: 3150 / 5352, loss: 0.005975, speed: 4.00 step/s
# epoch: 0 / 4, steps: 3200 / 5352, loss: 0.006820, speed: 3.96 step/s
# epoch: 0 / 4, steps: 3250 / 5352, loss: 0.005892, speed: 4.03 step/s
# epoch: 0 / 4, steps: 3300 / 5352, loss: 0.006155, speed: 4.07 step/s
# epoch: 0 / 4, steps: 3350 / 5352, loss: 0.006272, speed: 4.09 step/s
# epoch: 0 / 4, steps: 3400 / 5352, loss: 0.005514, speed: 4.15 step/s
# epoch: 0 / 4, steps: 3450 / 5352, loss: 0.006363, speed: 4.06 step/s
# epoch: 0 / 4, steps: 3500 / 5352, loss: 0.005279, speed: 3.94 step/s
# epoch: 0 / 4, steps: 3550 / 5352, loss: 0.005708, speed: 4.18 step/s
# epoch: 0 / 4, steps: 3600 / 5352, loss: 0.006090, speed: 4.17 step/s
# epoch: 0 / 4, steps: 3650 / 5352, loss: 0.005226, speed: 4.18 step/s
# epoch: 0 / 4, steps: 3700 / 5352, loss: 0.004717, speed: 4.18 step/s
# epoch: 0 / 4, steps: 3750 / 5352, loss: 0.004917, speed: 4.14 step/s
# epoch: 0 / 4, steps: 3800 / 5352, loss: 0.005994, speed: 4.17 step/s
# epoch: 0 / 4, steps: 3850 / 5352, loss: 0.004378, speed: 4.18 step/s
# epoch: 0 / 4, steps: 3900 / 5352, loss: 0.004899, speed: 4.04 step/s
# epoch: 0 / 4, steps: 3950 / 5352, loss: 0.005137, speed: 4.00 step/s
# epoch: 0 / 4, steps: 4000 / 5352, loss: 0.004567, speed: 3.95 step/s
# epoch: 0 / 4, steps: 4050 / 5352, loss: 0.005591, speed: 3.98 step/s
# epoch: 0 / 4, steps: 4100 / 5352, loss: 0.004703, speed: 3.98 step/s
# epoch: 0 / 4, steps: 4150 / 5352, loss: 0.004796, speed: 4.00 step/s
# epoch: 0 / 4, steps: 4200 / 5352, loss: 0.005750, speed: 4.01 step/s
# epoch: 0 / 4, steps: 4250 / 5352, loss: 0.004765, speed: 3.90 step/s
# epoch: 0 / 4, steps: 4300 / 5352, loss: 0.004267, speed: 4.01 step/s
# epoch: 0 / 4, steps: 4350 / 5352, loss: 0.005036, speed: 4.02 step/s
# epoch: 0 / 4, steps: 4400 / 5352, loss: 0.004024, speed: 4.06 step/s
# epoch: 0 / 4, steps: 4450 / 5352, loss: 0.005423, speed: 4.12 step/s
# epoch: 0 / 4, steps: 4500 / 5352, loss: 0.004136, speed: 4.11 step/s
# epoch: 0 / 4, steps: 4550 / 5352, loss: 0.003975, speed: 4.16 step/s
# epoch: 0 / 4, steps: 4600 / 5352, loss: 0.005827, speed: 4.17 step/s
# epoch: 0 / 4, steps: 4650 / 5352, loss: 0.005043, speed: 4.17 step/s
# epoch: 0 / 4, steps: 4700 / 5352, loss: 0.005264, speed: 4.16 step/s
# epoch: 0 / 4, steps: 4750 / 5352, loss: 0.005168, speed: 4.13 step/s
# epoch: 0 / 4, steps: 4800 / 5352, loss: 0.003452, speed: 4.14 step/s
# epoch: 0 / 4, steps: 4850 / 5352, loss: 0.003779, speed: 4.13 step/s
# epoch: 0 / 4, steps: 4900 / 5352, loss: 0.004297, speed: 4.18 step/s
# epoch: 0 / 4, steps: 4950 / 5352, loss: 0.004583, speed: 4.12 step/s
# epoch: 0 / 4, steps: 5000 / 5352, loss: 0.004432, speed: 3.97 step/s
# epoch: 0 / 4, steps: 5050 / 5352, loss: 0.003990, speed: 3.98 step/s
# epoch: 0 / 4, steps: 5100 / 5352, loss: 0.006043, speed: 4.00 step/s
# epoch: 0 / 4, steps: 5150 / 5352, loss: 0.003904, speed: 4.04 step/s
# epoch: 0 / 4, steps: 5200 / 5352, loss: 0.003158, speed: 4.02 step/s
# epoch: 0 / 4, steps: 5250 / 5352, loss: 0.004533, speed: 4.04 step/s
# epoch: 0 / 4, steps: 5300 / 5352, loss: 0.004566, speed: 4.01 step/s
# epoch: 0 / 4, steps: 5350 / 5352, loss: 0.003919, speed: 4.06 step/s
# epoch time footprint: 0 hour 21 min 43 sec
#
# =====start training of 1 epochs=====
# epoch: 1 / 4, steps: 48 / 5352, loss: 0.003886, speed: 4.00 step/s
# epoch: 1 / 4, steps: 98 / 5352, loss: 0.003928, speed: 4.11 step/s
# epoch: 1 / 4, steps: 148 / 5352, loss: 0.003345, speed: 4.12 step/s
# epoch: 1 / 4, steps: 198 / 5352, loss: 0.002710, speed: 4.15 step/s
# epoch: 1 / 4, steps: 248 / 5352, loss: 0.003041, speed: 4.23 step/s
# epoch: 1 / 4, steps: 298 / 5352, loss: 0.003445, speed: 4.18 step/s
# epoch: 1 / 4, steps: 348 / 5352, loss: 0.004666, speed: 4.19 step/s
# epoch: 1 / 4, steps: 398 / 5352, loss: 0.003664, speed: 4.18 step/s
# epoch: 1 / 4, steps: 448 / 5352, loss: 0.002626, speed: 4.16 step/s
# epoch: 1 / 4, steps: 498 / 5352, loss: 0.003744, speed: 4.21 step/s
# epoch: 1 / 4, steps: 548 / 5352, loss: 0.003494, speed: 4.21 step/s
# epoch: 1 / 4, steps: 598 / 5352, loss: 0.003882, speed: 4.18 step/s
# epoch: 1 / 4, steps: 648 / 5352, loss: 0.003261, speed: 4.18 step/s
# epoch: 1 / 4, steps: 698 / 5352, loss: 0.002917, speed: 4.17 step/s
# epoch: 1 / 4, steps: 748 / 5352, loss: 0.003194, speed: 4.07 step/s
# epoch: 1 / 4, steps: 798 / 5352, loss: 0.002957, speed: 4.05 step/s
# epoch: 1 / 4, steps: 848 / 5352, loss: 0.003002, speed: 4.07 step/s
# epoch: 1 / 4, steps: 898 / 5352, loss: 0.003959, speed: 4.05 step/s
# epoch: 1 / 4, steps: 948 / 5352, loss: 0.003035, speed: 4.06 step/s
# epoch: 1 / 4, steps: 998 / 5352, loss: 0.002685, speed: 4.07 step/s
# epoch: 1 / 4, steps: 1048 / 5352, loss: 0.003551, speed: 4.03 step/s
# epoch: 1 / 4, steps: 1098 / 5352, loss: 0.004240, speed: 4.03 step/s
# epoch: 1 / 4, steps: 1148 / 5352, loss: 0.003037, speed: 4.05 step/s
# epoch: 1 / 4, steps: 1198 / 5352, loss: 0.004114, speed: 2.34 step/s
# epoch: 1 / 4, steps: 1248 / 5352, loss: 0.003522, speed: 2.17 step/s
# epoch: 1 / 4, steps: 1298 / 5352, loss: 0.002659, speed: 2.31 step/s
# epoch: 1 / 4, steps: 1348 / 5352, loss: 0.002949, speed: 3.35 step/s
# epoch: 1 / 4, steps: 1398 / 5352, loss: 0.002198, speed: 4.25 step/s
# epoch: 1 / 4, steps: 1448 / 5352, loss: 0.003934, speed: 4.18 step/s
# epoch: 1 / 4, steps: 1498 / 5352, loss: 0.003336, speed: 4.22 step/s
# epoch: 1 / 4, steps: 1548 / 5352, loss: 0.002736, speed: 4.21 step/s
# epoch: 1 / 4, steps: 1598 / 5352, loss: 0.003055, speed: 4.10 step/s
# epoch: 1 / 4, steps: 1648 / 5352, loss: 0.003461, speed: 4.09 step/s
# epoch: 1 / 4, steps: 1698 / 5352, loss: 0.002718, speed: 4.18 step/s
# epoch: 1 / 4, steps: 1748 / 5352, loss: 0.002453, speed: 4.24 step/s
# epoch: 1 / 4, steps: 1798 / 5352, loss: 0.003003, speed: 4.20 step/s
# epoch: 1 / 4, steps: 1848 / 5352, loss: 0.003114, speed: 4.09 step/s
# epoch: 1 / 4, steps: 1898 / 5352, loss: 0.004024, speed: 4.07 step/s
# epoch: 1 / 4, steps: 1948 / 5352, loss: 0.003315, speed: 4.04 step/s
# epoch: 1 / 4, steps: 1998 / 5352, loss: 0.003013, speed: 4.08 step/s
# epoch: 1 / 4, steps: 2048 / 5352, loss: 0.003317, speed: 4.05 step/s
# epoch: 1 / 4, steps: 2098 / 5352, loss: 0.004446, speed: 4.06 step/s
# epoch: 1 / 4, steps: 2148 / 5352, loss: 0.003577, speed: 4.08 step/s
# epoch: 1 / 4, steps: 2198 / 5352, loss: 0.003372, speed: 4.06 step/s
# epoch: 1 / 4, steps: 2248 / 5352, loss: 0.003117, speed: 4.10 step/s
# epoch: 1 / 4, steps: 2298 / 5352, loss: 0.002535, speed: 4.11 step/s
# epoch: 1 / 4, steps: 2348 / 5352, loss: 0.003258, speed: 4.04 step/s
# epoch: 1 / 4, steps: 2398 / 5352, loss: 0.002943, speed: 3.95 step/s
# epoch: 1 / 4, steps: 2448 / 5352, loss: 0.002509, speed: 4.14 step/s
# epoch: 1 / 4, steps: 2498 / 5352, loss: 0.002667, speed: 4.18 step/s
# epoch: 1 / 4, steps: 2548 / 5352, loss: 0.002903, speed: 4.17 step/s
# epoch: 1 / 4, steps: 2598 / 5352, loss: 0.002421, speed: 4.17 step/s
# epoch: 1 / 4, steps: 2648 / 5352, loss: 0.002885, speed: 4.05 step/s
# epoch: 1 / 4, steps: 2698 / 5352, loss: 0.003693, speed: 4.17 step/s
# epoch: 1 / 4, steps: 2748 / 5352, loss: 0.003135, speed: 4.17 step/s
# epoch: 1 / 4, steps: 2798 / 5352, loss: 0.002570, speed: 4.20 step/s
# epoch: 1 / 4, steps: 2848 / 5352, loss: 0.003219, speed: 4.21 step/s
# epoch: 1 / 4, steps: 2898 / 5352, loss: 0.002203, speed: 4.18 step/s
# epoch: 1 / 4, steps: 2948 / 5352, loss: 0.003345, speed: 4.09 step/s
# epoch: 1 / 4, steps: 2998 / 5352, loss: 0.004129, speed: 4.06 step/s
# epoch: 1 / 4, steps: 3048 / 5352, loss: 0.002483, speed: 4.02 step/s
# epoch: 1 / 4, steps: 3098 / 5352, loss: 0.002969, speed: 4.02 step/s
# epoch: 1 / 4, steps: 3148 / 5352, loss: 0.003015, speed: 3.88 step/s
# epoch: 1 / 4, steps: 3198 / 5352, loss: 0.003442, speed: 4.08 step/s
# epoch: 1 / 4, steps: 3248 / 5352, loss: 0.003021, speed: 4.08 step/s
# epoch: 1 / 4, steps: 3298 / 5352, loss: 0.003992, speed: 4.07 step/s
# epoch: 1 / 4, steps: 3348 / 5352, loss: 0.002573, speed: 4.08 step/s
# epoch: 1 / 4, steps: 3398 / 5352, loss: 0.002970, speed: 4.01 step/s
# epoch: 1 / 4, steps: 3448 / 5352, loss: 0.002644, speed: 4.13 step/s
# epoch: 1 / 4, steps: 3498 / 5352, loss: 0.004550, speed: 4.17 step/s
# epoch: 1 / 4, steps: 3548 / 5352, loss: 0.003257, speed: 4.22 step/s
# epoch: 1 / 4, steps: 3598 / 5352, loss: 0.003780, speed: 4.24 step/s
# epoch: 1 / 4, steps: 3648 / 5352, loss: 0.004088, speed: 4.24 step/s
# epoch: 1 / 4, steps: 3698 / 5352, loss: 0.003398, speed: 4.03 step/s
# epoch: 1 / 4, steps: 3748 / 5352, loss: 0.003060, speed: 4.22 step/s
# epoch: 1 / 4, steps: 3798 / 5352, loss: 0.001915, speed: 4.23 step/s
# epoch: 1 / 4, steps: 3848 / 5352, loss: 0.002211, speed: 4.21 step/s
# epoch: 1 / 4, steps: 3898 / 5352, loss: 0.002386, speed: 4.25 step/s
# epoch: 1 / 4, steps: 3948 / 5352, loss: 0.002871, speed: 4.18 step/s
# epoch: 1 / 4, steps: 3998 / 5352, loss: 0.003702, speed: 4.22 step/s
# epoch: 1 / 4, steps: 4048 / 5352, loss: 0.002349, speed: 4.06 step/s
# epoch: 1 / 4, steps: 4098 / 5352, loss: 0.002234, speed: 4.08 step/s
# epoch: 1 / 4, steps: 4148 / 5352, loss: 0.002023, speed: 4.06 step/s
# epoch: 1 / 4, steps: 4198 / 5352, loss: 0.002388, speed: 4.05 step/s
# epoch: 1 / 4, steps: 4248 / 5352, loss: 0.003487, speed: 4.04 step/s
# epoch: 1 / 4, steps: 4298 / 5352, loss: 0.003149, speed: 4.16 step/s
# epoch: 1 / 4, steps: 4348 / 5352, loss: 0.002836, speed: 4.25 step/s
# epoch: 1 / 4, steps: 4398 / 5352, loss: 0.002342, speed: 4.21 step/s
# epoch: 1 / 4, steps: 4448 / 5352, loss: 0.002854, speed: 4.25 step/s
# epoch: 1 / 4, steps: 4498 / 5352, loss: 0.002644, speed: 4.22 step/s
# epoch: 1 / 4, steps: 4548 / 5352, loss: 0.002503, speed: 4.22 step/s
# epoch: 1 / 4, steps: 4598 / 5352, loss: 0.002216, speed: 4.25 step/s
# epoch: 1 / 4, steps: 4648 / 5352, loss: 0.002691, speed: 4.24 step/s
#
# =====start evaluating ckpt of 10000 steps=====
# 100%|██████████| 646/646 [01:00<00:00, 10.74it/s]
# eval loss: 0.002515
# precision: 61.94	 recall: 60.25	 f1: 61.08
# saving checkpoing model_10000.pdparams to checkpoints2
# epoch: 1 / 4, steps: 4698 / 5352, loss: 0.002809, speed: 0.62 step/s
# epoch: 1 / 4, steps: 4748 / 5352, loss: 0.003302, speed: 4.18 step/s
# epoch: 1 / 4, steps: 4798 / 5352, loss: 0.002504, speed: 3.96 step/s
# epoch: 1 / 4, steps: 4848 / 5352, loss: 0.002141, speed: 2.26 step/s
# epoch: 1 / 4, steps: 4898 / 5352, loss: 0.002362, speed: 2.27 step/s
# epoch: 1 / 4, steps: 4998 / 5352, loss: 0.002073, speed: 2.19 step/s
# epoch: 1 / 4, steps: 5048 / 5352, loss: 0.002721, speed: 2.19 step/s
# epoch: 1 / 4, steps: 5098 / 5352, loss: 0.002372, speed: 2.17 step/s
# epoch: 1 / 4, steps: 5148 / 5352, loss: 0.002679, speed: 2.24 step/s
# epoch: 1 / 4, steps: 5198 / 5352, loss: 0.002758, speed: 2.14 step/s
# epoch: 1 / 4, steps: 5248 / 5352, loss: 0.003271, speed: 2.20 step/s
# epoch: 1 / 4, steps: 5298 / 5352, loss: 0.003024, speed: 2.30 step/s
# epoch: 1 / 4, steps: 5348 / 5352, loss: 0.002742, speed: 2.13 step/s
# epoch time footprint: 0 hour 25 min 16 sec
#
# =====start training of 2 epochs=====
# epoch: 2 / 4, steps: 46 / 5352, loss: 0.002411, speed: 2.27 step/s
# epoch: 2 / 4, steps: 96 / 5352, loss: 0.002256, speed: 2.37 step/s
# epoch: 2 / 4, steps: 146 / 5352, loss: 0.002581, speed: 2.22 step/s
# epoch: 2 / 4, steps: 196 / 5352, loss: 0.001839, speed: 2.32 step/s
# epoch: 2 / 4, steps: 246 / 5352, loss: 0.002247, speed: 2.44 step/s
# epoch: 2 / 4, steps: 296 / 5352, loss: 0.002912, speed: 2.38 step/s
# epoch: 2 / 4, steps: 346 / 5352, loss: 0.002251, speed: 4.10 step/s
# epoch: 2 / 4, steps: 396 / 5352, loss: 0.002559, speed: 4.11 step/s
# epoch: 2 / 4, steps: 446 / 5352, loss: 0.002808, speed: 4.05 step/s
# epoch: 2 / 4, steps: 496 / 5352, loss: 0.003114, speed: 4.10 step/s
# epoch: 2 / 4, steps: 546 / 5352, loss: 0.002079, speed: 4.05 step/s
# epoch: 2 / 4, steps: 596 / 5352, loss: 0.003026, speed: 4.06 step/s
# epoch: 2 / 4, steps: 646 / 5352, loss: 0.001807, speed: 4.08 step/s
# epoch: 2 / 4, steps: 696 / 5352, loss: 0.002781, speed: 3.88 step/s
# epoch: 2 / 4, steps: 746 / 5352, loss: 0.002722, speed: 3.92 step/s
# epoch: 2 / 4, steps: 796 / 5352, loss: 0.002027, speed: 3.99 step/s
# epoch: 2 / 4, steps: 846 / 5352, loss: 0.001507, speed: 4.00 step/s
# epoch: 2 / 4, steps: 896 / 5352, loss: 0.002041, speed: 4.00 step/s
# epoch: 2 / 4, steps: 946 / 5352, loss: 0.002220, speed: 3.90 step/s
# epoch: 2 / 4, steps: 996 / 5352, loss: 0.003219, speed: 4.00 step/s
# epoch: 2 / 4, steps: 1046 / 5352, loss: 0.001678, speed: 4.03 step/s
# epoch: 2 / 4, steps: 1096 / 5352, loss: 0.002768, speed: 4.07 step/s
# epoch: 2 / 4, steps: 1146 / 5352, loss: 0.001608, speed: 4.09 step/s
# epoch: 2 / 4, steps: 1196 / 5352, loss: 0.002302, speed: 4.10 step/s
# epoch: 2 / 4, steps: 1246 / 5352, loss: 0.001680, speed: 4.16 step/s
# epoch: 2 / 4, steps: 1296 / 5352, loss: 0.002260, speed: 4.18 step/s
# epoch: 2 / 4, steps: 1346 / 5352, loss: 0.002148, speed: 4.18 step/s
# epoch: 2 / 4, steps: 1396 / 5352, loss: 0.002105, speed: 4.19 step/s
# epoch: 2 / 4, steps: 1446 / 5352, loss: 0.002652, speed: 3.98 step/s
# epoch: 2 / 4, steps: 1496 / 5352, loss: 0.002776, speed: 4.19 step/s
# epoch: 2 / 4, steps: 1546 / 5352, loss: 0.001505, speed: 4.17 step/s
# epoch: 2 / 4, steps: 1596 / 5352, loss: 0.002281, speed: 4.18 step/s
# epoch: 2 / 4, steps: 1646 / 5352, loss: 0.001925, speed: 4.17 step/s
# epoch: 2 / 4, steps: 1696 / 5352, loss: 0.002310, speed: 4.18 step/s
# epoch: 2 / 4, steps: 1746 / 5352, loss: 0.002086, speed: 3.99 step/s
# epoch: 2 / 4, steps: 1796 / 5352, loss: 0.002288, speed: 3.99 step/s
# epoch: 2 / 4, steps: 1846 / 5352, loss: 0.002115, speed: 4.06 step/s
# epoch: 2 / 4, steps: 1896 / 5352, loss: 0.002094, speed: 3.98 step/s
# epoch: 2 / 4, steps: 1946 / 5352, loss: 0.001835, speed: 4.02 step/s
# epoch: 2 / 4, steps: 1996 / 5352, loss: 0.002277, speed: 3.94 step/s
# epoch: 2 / 4, steps: 2046 / 5352, loss: 0.001986, speed: 4.03 step/s
# epoch: 2 / 4, steps: 2096 / 5352, loss: 0.001888, speed: 4.03 step/s
# epoch: 2 / 4, steps: 2146 / 5352, loss: 0.001591, speed: 4.06 step/s
# epoch: 2 / 4, steps: 2196 / 5352, loss: 0.002085, speed: 4.07 step/s
# epoch: 2 / 4, steps: 2246 / 5352, loss: 0.002408, speed: 3.83 step/s
# epoch: 2 / 4, steps: 2296 / 5352, loss: 0.002567, speed: 4.12 step/s
# epoch: 2 / 4, steps: 2346 / 5352, loss: 0.001727, speed: 4.19 step/s
# epoch: 2 / 4, steps: 2396 / 5352, loss: 0.002163, speed: 4.19 step/s
# epoch: 2 / 4, steps: 2446 / 5352, loss: 0.001803, speed: 4.19 step/s
# epoch: 2 / 4, steps: 2496 / 5352, loss: 0.002677, speed: 4.01 step/s
# epoch: 2 / 4, steps: 2546 / 5352, loss: 0.002549, speed: 4.19 step/s
# epoch: 2 / 4, steps: 2596 / 5352, loss: 0.002226, speed: 4.21 step/s
# epoch: 2 / 4, steps: 2646 / 5352, loss: 0.002084, speed: 4.21 step/s
# epoch: 2 / 4, steps: 2696 / 5352, loss: 0.002493, speed: 4.22 step/s
# epoch: 2 / 4, steps: 2746 / 5352, loss: 0.002163, speed: 4.17 step/s
# epoch: 2 / 4, steps: 2796 / 5352, loss: 0.002371, speed: 4.19 step/s
# epoch: 2 / 4, steps: 2846 / 5352, loss: 0.004062, speed: 4.12 step/s
# epoch: 2 / 4, steps: 2896 / 5352, loss: 0.001724, speed: 4.03 step/s
# epoch: 2 / 4, steps: 2946 / 5352, loss: 0.002831, speed: 4.04 step/s
# epoch: 2 / 4, steps: 2996 / 5352, loss: 0.002335, speed: 4.01 step/s
# epoch: 2 / 4, steps: 3046 / 5352, loss: 0.001516, speed: 4.01 step/s
# epoch: 2 / 4, steps: 3096 / 5352, loss: 0.002998, speed: 4.04 step/s
# epoch: 2 / 4, steps: 3146 / 5352, loss: 0.002577, speed: 4.05 step/s
# epoch: 2 / 4, steps: 3196 / 5352, loss: 0.002116, speed: 4.04 step/s
# epoch: 2 / 4, steps: 3246 / 5352, loss: 0.001794, speed: 4.03 step/s
# epoch: 2 / 4, steps: 3296 / 5352, loss: 0.002351, speed: 4.05 step/s
# epoch: 2 / 4, steps: 3346 / 5352, loss: 0.001450, speed: 4.06 step/s
# epoch: 2 / 4, steps: 3396 / 5352, loss: 0.002919, speed: 4.07 step/s
# epoch: 2 / 4, steps: 3446 / 5352, loss: 0.002204, speed: 4.20 step/s
# epoch: 2 / 4, steps: 3496 / 5352, loss: 0.002916, speed: 4.22 step/s
# epoch: 2 / 4, steps: 3546 / 5352, loss: 0.002897, speed: 4.17 step/s
# epoch: 2 / 4, steps: 3596 / 5352, loss: 0.002174, speed: 4.16 step/s
# epoch: 2 / 4, steps: 3646 / 5352, loss: 0.002225, speed: 4.22 step/s
# epoch: 2 / 4, steps: 3696 / 5352, loss: 0.002833, speed: 4.21 step/s
# epoch: 2 / 4, steps: 3746 / 5352, loss: 0.001857, speed: 4.22 step/s
# epoch: 2 / 4, steps: 3796 / 5352, loss: 0.001777, speed: 4.16 step/s
# epoch: 2 / 4, steps: 3846 / 5352, loss: 0.001799, speed: 4.20 step/s
# epoch: 2 / 4, steps: 3896 / 5352, loss: 0.002218, speed: 4.21 step/s
# epoch: 2 / 4, steps: 3946 / 5352, loss: 0.002024, speed: 4.17 step/s
# epoch: 2 / 4, steps: 3996 / 5352, loss: 0.002162, speed: 4.04 step/s
# epoch: 2 / 4, steps: 4046 / 5352, loss: 0.003442, speed: 4.01 step/s
# epoch: 2 / 4, steps: 4096 / 5352, loss: 0.002801, speed: 4.04 step/s
# epoch: 2 / 4, steps: 4146 / 5352, loss: 0.002278, speed: 4.05 step/s
# epoch: 2 / 4, steps: 4196 / 5352, loss: 0.002175, speed: 4.06 step/s
# epoch: 2 / 4, steps: 4246 / 5352, loss: 0.002758, speed: 4.05 step/s
# epoch: 2 / 4, steps: 4296 / 5352, loss: 0.002793, speed: 3.93 step/s
# epoch: 2 / 4, steps: 4346 / 5352, loss: 0.001861, speed: 4.05 step/s
# epoch: 2 / 4, steps: 4396 / 5352, loss: 0.002318, speed: 4.06 step/s
# epoch: 2 / 4, steps: 4446 / 5352, loss: 0.002484, speed: 4.08 step/s
# epoch: 2 / 4, steps: 4496 / 5352, loss: 0.002217, speed: 4.11 step/s
# epoch: 2 / 4, steps: 4546 / 5352, loss: 0.002120, speed: 4.15 step/s
# epoch: 2 / 4, steps: 4596 / 5352, loss: 0.002857, speed: 4.14 step/s
# epoch: 2 / 4, steps: 4646 / 5352, loss: 0.001748, speed: 4.23 step/s
# epoch: 2 / 4, steps: 4696 / 5352, loss: 0.002111, speed: 4.22 step/s
# epoch: 2 / 4, steps: 4746 / 5352, loss: 0.002674, speed: 4.20 step/s
# epoch: 2 / 4, steps: 4796 / 5352, loss: 0.002114, speed: 4.20 step/s
# epoch: 2 / 4, steps: 4846 / 5352, loss: 0.002157, speed: 4.16 step/s
# epoch: 2 / 4, steps: 4896 / 5352, loss: 0.001569, speed: 4.17 step/s
# epoch: 2 / 4, steps: 4946 / 5352, loss: 0.002149, speed: 4.21 step/s
# epoch: 2 / 4, steps: 4996 / 5352, loss: 0.001525, speed: 4.19 step/s
# epoch: 2 / 4, steps: 5046 / 5352, loss: 0.002269, speed: 4.20 step/s
# epoch: 2 / 4, steps: 5096 / 5352, loss: 0.001783, speed: 4.02 step/s
# epoch: 2 / 4, steps: 5146 / 5352, loss: 0.001468, speed: 4.05 step/s
# epoch: 2 / 4, steps: 5196 / 5352, loss: 0.001789, speed: 4.05 step/s
# epoch: 2 / 4, steps: 5246 / 5352, loss: 0.002838, speed: 4.04 step/s
# epoch: 2 / 4, steps: 5296 / 5352, loss: 0.001672, speed: 4.05 step/s
# epoch: 2 / 4, steps: 5346 / 5352, loss: 0.002561, speed: 4.01 step/s
# epoch time footprint: 0 hour 22 min 43 sec
#
# =====start training of 3 epochs=====
# epoch: 3 / 4, steps: 44 / 5352, loss: 0.001801, speed: 4.05 step/s
# epoch: 3 / 4, steps: 94 / 5352, loss: 0.001557, speed: 4.01 step/s
# epoch: 3 / 4, steps: 144 / 5352, loss: 0.002605, speed: 3.99 step/s
# epoch: 3 / 4, steps: 194 / 5352, loss: 0.001649, speed: 4.00 step/s
# epoch: 3 / 4, steps: 244 / 5352, loss: 0.001443, speed: 3.93 step/s
# epoch: 3 / 4, steps: 294 / 5352, loss: 0.002577, speed: 4.17 step/s
# epoch: 3 / 4, steps: 344 / 5352, loss: 0.001971, speed: 4.21 step/s
# epoch: 3 / 4, steps: 394 / 5352, loss: 0.002470, speed: 4.20 step/s
# epoch: 3 / 4, steps: 444 / 5352, loss: 0.002391, speed: 4.20 step/s
# epoch: 3 / 4, steps: 494 / 5352, loss: 0.002345, speed: 4.14 step/s
# epoch: 3 / 4, steps: 544 / 5352, loss: 0.002324, speed: 4.15 step/s
# epoch: 3 / 4, steps: 594 / 5352, loss: 0.002116, speed: 4.23 step/s
# epoch: 3 / 4, steps: 644 / 5352, loss: 0.001498, speed: 4.20 step/s
# epoch: 3 / 4, steps: 694 / 5352, loss: 0.002686, speed: 4.21 step/s
# epoch: 3 / 4, steps: 744 / 5352, loss: 0.001354, speed: 4.21 step/s
# epoch: 3 / 4, steps: 794 / 5352, loss: 0.004069, speed: 4.10 step/s
# epoch: 3 / 4, steps: 844 / 5352, loss: 0.001871, speed: 4.01 step/s
# epoch: 3 / 4, steps: 894 / 5352, loss: 0.002501, speed: 4.00 step/s
# epoch: 3 / 4, steps: 944 / 5352, loss: 0.001922, speed: 4.00 step/s
# epoch: 3 / 4, steps: 994 / 5352, loss: 0.001998, speed: 3.99 step/s
# epoch: 3 / 4, steps: 1044 / 5352, loss: 0.001829, speed: 3.95 step/s
# epoch: 3 / 4, steps: 1094 / 5352, loss: 0.001648, speed: 4.01 step/s
# epoch: 3 / 4, steps: 1144 / 5352, loss: 0.001267, speed: 4.01 step/s
# epoch: 3 / 4, steps: 1194 / 5352, loss: 0.001909, speed: 4.00 step/s
# epoch: 3 / 4, steps: 1244 / 5352, loss: 0.002165, speed: 4.06 step/s
# epoch: 3 / 4, steps: 1294 / 5352, loss: 0.001701, speed: 4.02 step/s
# epoch: 3 / 4, steps: 1344 / 5352, loss: 0.001954, speed: 4.07 step/s
# epoch: 3 / 4, steps: 1394 / 5352, loss: 0.001528, speed: 4.18 step/s
# epoch: 3 / 4, steps: 1444 / 5352, loss: 0.002012, speed: 4.20 step/s
# epoch: 3 / 4, steps: 1494 / 5352, loss: 0.002637, speed: 4.17 step/s
# epoch: 3 / 4, steps: 1544 / 5352, loss: 0.002625, speed: 4.04 step/s
# epoch: 3 / 4, steps: 1594 / 5352, loss: 0.002310, speed: 4.13 step/s
# epoch: 3 / 4, steps: 1644 / 5352, loss: 0.002112, speed: 4.16 step/s
# epoch: 3 / 4, steps: 1694 / 5352, loss: 0.001502, speed: 4.19 step/s
# epoch: 3 / 4, steps: 1744 / 5352, loss: 0.002353, speed: 4.18 step/s
# epoch: 3 / 4, steps: 1794 / 5352, loss: 0.002056, speed: 4.13 step/s
# epoch: 3 / 4, steps: 1844 / 5352, loss: 0.002092, speed: 4.17 step/s
# epoch: 3 / 4, steps: 1894 / 5352, loss: 0.002064, speed: 4.16 step/s
# epoch: 3 / 4, steps: 1944 / 5352, loss: 0.002545, speed: 4.03 step/s
# epoch: 3 / 4, steps: 1994 / 5352, loss: 0.001745, speed: 4.04 step/s
# epoch: 3 / 4, steps: 2044 / 5352, loss: 0.001912, speed: 3.93 step/s
# epoch: 3 / 4, steps: 2094 / 5352, loss: 0.001745, speed: 3.97 step/s
# epoch: 3 / 4, steps: 2144 / 5352, loss: 0.001671, speed: 3.98 step/s
# epoch: 3 / 4, steps: 2194 / 5352, loss: 0.002639, speed: 3.98 step/s
# epoch: 3 / 4, steps: 2244 / 5352, loss: 0.001564, speed: 4.01 step/s
# epoch: 3 / 4, steps: 2294 / 5352, loss: 0.002052, speed: 3.95 step/s
# epoch: 3 / 4, steps: 2344 / 5352, loss: 0.002292, speed: 4.01 step/s
# epoch: 3 / 4, steps: 2394 / 5352, loss: 0.001602, speed: 4.08 step/s
# epoch: 3 / 4, steps: 2444 / 5352, loss: 0.002753, speed: 4.12 step/s
# epoch: 3 / 4, steps: 2494 / 5352, loss: 0.002333, speed: 4.19 step/s
# epoch: 3 / 4, steps: 2544 / 5352, loss: 0.001804, speed: 4.12 step/s
# epoch: 3 / 4, steps: 2594 / 5352, loss: 0.002340, speed: 4.15 step/s
# epoch: 3 / 4, steps: 2644 / 5352, loss: 0.002085, speed: 4.17 step/s
# epoch: 3 / 4, steps: 2694 / 5352, loss: 0.001647, speed: 4.17 step/s
# epoch: 3 / 4, steps: 2744 / 5352, loss: 0.001905, speed: 4.22 step/s
# epoch: 3 / 4, steps: 2794 / 5352, loss: 0.001530, speed: 4.18 step/s
# epoch: 3 / 4, steps: 2844 / 5352, loss: 0.002067, speed: 4.16 step/s
# epoch: 3 / 4, steps: 2894 / 5352, loss: 0.001521, speed: 4.16 step/s
# epoch: 3 / 4, steps: 2944 / 5352, loss: 0.001818, speed: 4.19 step/s
# epoch: 3 / 4, steps: 2994 / 5352, loss: 0.001739, speed: 4.05 step/s
# epoch: 3 / 4, steps: 3044 / 5352, loss: 0.002240, speed: 4.00 step/s
# epoch: 3 / 4, steps: 3094 / 5352, loss: 0.002368, speed: 3.95 step/s
# epoch: 3 / 4, steps: 3144 / 5352, loss: 0.001876, speed: 3.96 step/s
# epoch: 3 / 4, steps: 3194 / 5352, loss: 0.002106, speed: 3.99 step/s
# epoch: 3 / 4, steps: 3244 / 5352, loss: 0.002344, speed: 3.99 step/s
# epoch: 3 / 4, steps: 3294 / 5352, loss: 0.002498, speed: 3.99 step/s
# epoch: 3 / 4, steps: 3344 / 5352, loss: 0.001505, speed: 3.93 step/s
# epoch: 3 / 4, steps: 3394 / 5352, loss: 0.002749, speed: 4.00 step/s
# epoch: 3 / 4, steps: 3444 / 5352, loss: 0.001637, speed: 4.01 step/s
# epoch: 3 / 4, steps: 3494 / 5352, loss: 0.002314, speed: 4.03 step/s
# epoch: 3 / 4, steps: 3544 / 5352, loss: 0.001989, speed: 4.11 step/s
# epoch: 3 / 4, steps: 3594 / 5352, loss: 0.001894, speed: 4.14 step/s
# epoch: 3 / 4, steps: 3644 / 5352, loss: 0.001952, speed: 4.19 step/s
# epoch: 3 / 4, steps: 3694 / 5352, loss: 0.002019, speed: 4.20 step/s
# epoch: 3 / 4, steps: 3744 / 5352, loss: 0.003383, speed: 4.21 step/s
# epoch: 3 / 4, steps: 3794 / 5352, loss: 0.002440, speed: 4.18 step/s
# epoch: 3 / 4, steps: 3844 / 5352, loss: 0.001444, speed: 2.31 step/s
# epoch: 3 / 4, steps: 3894 / 5352, loss: 0.002331, speed: 2.33 step/s
# epoch: 3 / 4, steps: 3944 / 5352, loss: 0.001685, speed: 2.32 step/s
#
# =====start evaluating ckpt of 20000 steps=====
# 100%|██████████| 646/646 [01:00<00:00, 10.65it/s]
# eval loss: 0.002201
# precision: 61.28	 recall: 68.28	 f1: 64.59
# saving checkpoing model_20000.pdparams to checkpoints2
# epoch: 3 / 4, steps: 3994 / 5352, loss: 0.002539, speed: 0.60 step/s
# epoch: 3 / 4, steps: 4044 / 5352, loss: 0.001598, speed: 4.03 step/s
# epoch: 3 / 4, steps: 4094 / 5352, loss: 0.001929, speed: 4.03 step/s
# epoch: 3 / 4, steps: 4144 / 5352, loss: 0.002342, speed: 4.04 step/s
# epoch: 3 / 4, steps: 4194 / 5352, loss: 0.002200, speed: 4.00 step/s
# epoch: 3 / 4, steps: 4244 / 5352, loss: 0.002072, speed: 4.04 step/s
# epoch: 3 / 4, steps: 4294 / 5352, loss: 0.001863, speed: 4.07 step/s
# epoch: 3 / 4, steps: 4344 / 5352, loss: 0.002052, speed: 4.12 step/s
# epoch: 3 / 4, steps: 4394 / 5352, loss: 0.003771, speed: 4.16 step/s
# epoch: 3 / 4, steps: 4444 / 5352, loss: 0.001861, speed: 4.20 step/s
# epoch: 3 / 4, steps: 4494 / 5352, loss: 0.001817, speed: 4.08 step/s
# epoch: 3 / 4, steps: 4544 / 5352, loss: 0.001276, speed: 4.22 step/s
# epoch: 3 / 4, steps: 4594 / 5352, loss: 0.002444, speed: 4.16 step/s
# epoch: 3 / 4, steps: 4644 / 5352, loss: 0.002121, speed: 4.21 step/s
# epoch: 3 / 4, steps: 4694 / 5352, loss: 0.002705, speed: 4.21 step/s
# epoch: 3 / 4, steps: 4744 / 5352, loss: 0.001550, speed: 4.15 step/s
# epoch: 3 / 4, steps: 4794 / 5352, loss: 0.001308, speed: 4.22 step/s
# epoch: 3 / 4, steps: 4844 / 5352, loss: 0.002752, speed: 4.21 step/s
# epoch: 3 / 4, steps: 4894 / 5352, loss: 0.002528, speed: 4.21 step/s
# epoch: 3 / 4, steps: 4944 / 5352, loss: 0.002451, speed: 4.03 step/s
# epoch: 3 / 4, steps: 4994 / 5352, loss: 0.002380, speed: 3.93 step/s
# epoch: 3 / 4, steps: 5044 / 5352, loss: 0.002444, speed: 3.98 step/s
# epoch: 3 / 4, steps: 5094 / 5352, loss: 0.001318, speed: 4.05 step/s
# epoch: 3 / 4, steps: 5144 / 5352, loss: 0.001993, speed: 4.05 step/s
# epoch: 3 / 4, steps: 5194 / 5352, loss: 0.002159, speed: 4.04 step/s
# epoch: 3 / 4, steps: 5244 / 5352, loss: 0.001620, speed: 4.02 step/s
# epoch: 3 / 4, steps: 5294 / 5352, loss: 0.002616, speed: 4.07 step/s
# epoch: 3 / 4, steps: 5344 / 5352, loss: 0.002692, speed: 4.10 step/s
# epoch time footprint: 0 hour 23 min 28 sec
#
# =====start evaluating last ckpt of 21408 steps=====
# 100%|██████████| 646/646 [01:00<00:00, 10.67it/s]
# eval loss: 0.002191
# precision: 61.80	 recall: 68.14	 f1: 64.81
#
# =====training complete=====

# %% [markdown]
# 上面添加了Visual DL的代码，所以可以观察到loss的逐渐降低
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/cab99bba0585455b85be7776dc56e2d8810d513f86004dd99caa0f8914dde641)

# %%
# !bash predict.sh
# Out:
# + export CUDA_VISIBLE_DEVICES=0
# + CUDA_VISIBLE_DEVICES=0
# + export BATCH_SIZE=8
# + BATCH_SIZE=8
# + export CKPT=./checkpoints/model_10704.pdparams
# + CKPT=./checkpoints/model_10704.pdparams
# + export DATASET_FILE=./data/test_data.json
# + DATASET_FILE=./data/test_data.json
# + python run_duie.py --do_predict --init_checkpoint ./checkpoints/model_10704.pdparams --predict_data_file ./data/test_data.json --max_seq_length 512 --batch_size 8
# [2021-06-12 13:02:39,758] [    INFO] - Already cached /home/aistudio/.paddlenlp/models/ernie-1.0/ernie_v1_chn_base.pdparams
# W0612 13:02:39.759878  4019 device_context.cc:404] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0612 13:02:39.765166  4019 device_context.cc:422] device: 0, cuDNN Version: 7.6.
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1297: UserWarning: Skip loading for classifier.weight. classifier.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1297: UserWarning: Skip loading for classifier.bias. classifier.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# [2021-06-12 13:02:46,498] [    INFO] - Found /home/aistudio/.paddlenlp/models/ernie-1.0/vocab.txt
# [2021-06-12 13:02:46,516] [    INFO] - Preprocessing data, loaded from ./data/test_data.json
# 100%|██████████████████████████████████████| 1000/1000 [00:04<00:00, 231.89it/s]
#
# =====start predicting=====
# 100%|█████████████████████████████████████████| 125/125 [00:11<00:00, 10.42it/s]
# eval loss: 0.052881
# =====predicting complete=====

# %% [markdown]
# 预测结果会被保存在data/predictions.json，data/predictions.json.zip，其格式与原数据集文件一致。
#
# 之后可以使用官方评估脚本评估训练模型在dev_data.json上的效果。如：
#
# ```shell
# python re_official_evaluation.py --golden_file=dev_data.json  --predict_file=predicitons.json.zip [--alias_file alias_dict]
# ```
# 输出指标为Precision, Recall 和 F1，Alias file包含了合法的实体别名，最终评测的时候会使用，这里不予提供。
#
# 之后在test_data.json上预测，然后预测结果（.zip文件）至[千言评测页面](https://aistudio.baidu.com/aistudio/competition/detail/46)。

# %% [markdown]
# 提交结果：
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/d959407dc6014aa4bdbf4da90a3d511207734d54f20d4360a8ae9be1151c8bc2)

# %% [markdown]
# ## Tricks
#
# ### 尝试更多的预训练模型
#
# 基线采用的预训练模型为ERNIE，PaddleNLP提供了丰富的预训练模型，如BERT，RoBERTa，Electra，XLNet等
# 参考[预训练模型文档](https://paddlenlp.readthedocs.io/zh/latest/model_zoo/transformers.html)
#
# 如可以选择RoBERTa large中文模型优化模型效果，只需更换模型和tokenizer即可无缝衔接。

# %%
from paddlenlp.transformers import RobertaForTokenClassification, RobertaTokenizer

model = RobertaForTokenClassification.from_pretrained(
    "roberta-wwm-ext-large",
    num_classes=(len(label_map) - 2) * 2 + 2)
tokenizer = RobertaTokenizer.from_pretrained("roberta-wwm-ext-large")

# %% [markdown]
# ### 模型集成
#
# 使用多个模型进行训练预测，将各个模型预测结果进行融合。

# %% [markdown]
# 以上基线实现基于PaddleNLP，开源不易，希望大家多多支持~
# **记得给[PaddleNLP](https://github.com/PaddlePaddle/PaddleNLP)点个小小的Star⭐，及时跟踪最新消息和功能哦**
#
# GitHub地址：[https://github.com/PaddlePaddle/PaddleNLP](https://github.com/PaddlePaddle/PaddleNLP)
